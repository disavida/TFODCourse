# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)

# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %% [markdown]
# # 2. Define Images to Collect

# %%
labels = ['D.magna']
number_imgs = 12

# %% [markdown]
# # 3. Setup Folders

# %%
IMAGES_PATH = os.path.join('images')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # 4. Capture Images

# %%
for label in labels:
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for D.magna
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11

# %% [markdown]
# # 5. Image Labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Collecting pyqt5
#   Using cached PyQt5-5.15.4-cp36.cp37.cp38.cp39-none-win_amd64.whl (6.8 MB)
# Collecting lxml
#   Using cached lxml-4.6.3-cp38-cp38-win_amd64.whl (3.5 MB)
# Collecting PyQt5-sip<13,>=12.8
#   Using cached PyQt5_sip-12.9.0-cp38-cp38-win_amd64.whl (63 kB)
# Collecting PyQt5-Qt5>=5.15
#   Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
# Installing collected packages: PyQt5-sip, PyQt5-Qt5, pyqt5, lxml
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.9.0 lxml-4.6.3 pyqt5-5.15.4

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}

# %%
if os.name == 'posix':
    # !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Image:C:\Users\disav\Desktop\Universidad\CICA\Tensorflow Daphnia Counter\TFODCourse\images\D.magna\2_11.jpg -> Annotation:C:/Users/disav/Desktop/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse/images/D.magna/2_11.xml
# Image:C:\Users\disav\Desktop\Universidad\CICA\Tensorflow Daphnia Counter\TFODCourse\images\D.magna\2_46.jpg -> Annotation:C:/Users/disav/Desktop/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse/images/D.magna/2_46.xml
# Cancel creation.
# Cancel creation.
# Image:C:\Users\disav\Desktop\Universidad\CICA\Tensorflow Daphnia Counter\TFODCourse\images\D.magna\5_93.jpg -> Annotation:C:/Users/disav/Desktop/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse/images/D.magna/5_93.xml
# Image:C:\Users\disav\Desktop\Universidad\CICA\Tensorflow Daphnia Counter\TFODCourse\images\D.magna\6c1.jpg -> Annotation:C:/Users/disav/Desktop/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse/images/D.magna/6c1.xml
# Image:C:\Users\disav\Desktop\Universidad\CICA\Tensorflow Daphnia Counter\TFODCourse\images\D.magna\6c4.jpg -> Annotation:C:/Users/disav/Desktop/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse/images/D.magna/6c4.xml
# Image:C:\Users\disav\Desktop\Universidad\CICA\Tensorflow Daphnia Counter\TFODCourse\images\D.magna\6c.jpg -> Annotation:C:/Users/disav/Desktop/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse/images/D.magna/6c.xml
# Image:C:\Users\disav\Desktop\Universidad\CICA\Tensorflow Daphnia Counter\TFODCourse\images\D.magna\6c_edit_33600249630809.jpg -> Annotation:C:/Users/disav/Desktop/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse/images/D.magna/6c_edit_33600249630809.xml
# Image:C:\Users\disav\Desktop\Universidad\CICA\Tensorflow Daphnia Counter\TFODCourse\images\D.magna\7_58.jpg -> Annotation:C:/Users/disav/Desktop/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse/images/D.magna/7_58.xml
# Image:C:\Users\disav\Desktop\Universidad\CICA\Tensorflow Daphnia Counter\TFODCourse\images\D.magna\093_3.jpg -> Annotation:C:/Users/disav/Desktop/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse/images/D.magna/093_3.xml
# Image:C:\Users\disav\Desktop\Universidad\CICA\Tensorflow Daphnia Counter\TFODCourse\images\D.magna\20210810_143425.jpg -> Annotation:C:/Users/disav/Desktop/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse/images/D.magna/20210810_143425.xml
# Cancel creation.
# Image:C:\Users\disav\Desktop\Universidad\CICA\Tensorflow Daphnia Counter\TFODCourse\images\D.magna\20210812_132428.jpg -> Annotation:C:/Users/disav/Desktop/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse/images/D.magna/20210812_132428.xml
# Image:C:\Users\disav\Desktop\Universidad\CICA\Tensorflow Daphnia Counter\TFODCourse\images\D.magna\20210812_132659.jpg -> Annotation:C:/Users/disav/Desktop/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse/images/D.magna/20210812_132659.xml
# labelImg.py:971: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   self.zoom_widget.setValue(value)
# labelImg.py:1025: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   h_bar.setValue(new_h_bar_value)
# labelImg.py:1026: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   v_bar.setValue(new_v_bar_value)
# labelImg.py:965: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   bar.setValue(bar.value() + bar.singleStep() * units)

# %% [markdown]
# # 6. Move them into a Training and Testing Partition

# %% [markdown]
# # OPTIONAL - 7. Compress them for Colab Training

# %%
# %cd /content/drive/Othercomputers/Mi Portátil/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse
# Out:
# /content/drive/Othercomputers/Mi Portátil/Universidad/CICA/Tensorflow Daphnia Counter/TFODCourse

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
TRAIN_PATH = os.path.join('images', 'train')
TEST_PATH = os.path.join('images', 'test')
ARCHIVE_PATH = os.path.join('images', 'archive.tar.gz')

# %%
# !tar -czf {ARCHIVE_PATH} {TRAIN_PATH} {TEST_PATH}
